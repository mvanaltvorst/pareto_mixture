# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import seaborn as sns
import pyparetomixture.fit as pm
import pyparetomixture.type as pmt
from loguru import logger
import sys

logger.remove()
logger.add(sys.stdout, colorize=True, level="DEBUG")
None

# %%
# generate data
n = 10000
p = 0.95
alpha = 2.0
beta = 3.0  # beta > alpha


def generate_data(n, p, alpha, beta):
    x = np.random.binomial(1, p, n)
    rv_alpha = np.random.pareto(alpha, n)
    rv_beta = np.random.pareto(beta, n)
    return x * rv_alpha + (1 - x) * rv_beta


data = generate_data(n, p, alpha, beta)
logger.debug(
    f"Generated a sample of length {len(data)}. Mean: {np.mean(data)}, std: {np.std(data)}"
)
# Out:
# 2023-04-05 20:28:24.035 | DEBUG    | __main__:<module>:16 - Generated a sample of length 10000. Mean: 0.9488068780987603, std: 2.2457484351925068

# %%
def pot(full_sample, k):
    full_sample.sort()
    return (full_sample[-k:] / full_sample[-k - 1]).copy()


def hill(sample):
    # hill estimate
    k = len(sample)
    assert (sample >= 1).all(), "not a pot sample"
    return k / (np.sum(np.log(sample)))


sample = pot(data, 200)
logger.debug(f"Generated pot sample. Min: {np.min(sample)}, max: {np.max(sample)}")
# Out:
# 2023-04-05 20:28:24.101 | DEBUG    | __main__:<module>:14 - Generated pot sample. Min: 1.000728990410609, max: 12.468327486729253

# %%
def backtracking_line_search(
    sample, pmp, direction, p_greater_than_1, pre_normalize=True
):
    # backtracking line search
    # https://en.wikipedia.org/wiki/Backtracking_line_search

    old_ll = pm.loglikelihood(pmp, sample)
    logger.debug(
        f"Doing backtracking line search in direction {direction}. Old ll: {old_ll}"
    )

    if pre_normalize:
        direction = direction * (1 / np.linalg.norm(np.array([direction.dalpha, direction.dbeta, direction.dp])))
        logger.debug(f"We normalize our direction: {direction}")

    multiplier = 0.5
    for _ in range(100):
        new_pmp = pmp + direction * multiplier
        logger.debug(f"New pmp in backtracking line search: {new_pmp}")

        # we ensure our new pmp do not surpass the thresholds we are given
        if not p_greater_than_1 and new_pmp.p >= 1:
            logger.debug(f"Encountered p >= 1 in {pmp} where p should be < 1")
            new_ll = -np.inf
        elif p_greater_than_1 and new_pmp.p <= 1:
            logger.debug(f"Encountered p <= 1 in {pmp} where p should be > 1")
            new_ll = -np.inf
        else:
            new_ll = pm.loglikelihood(new_pmp, sample)

        if new_ll == np.nan:
            logger.debug(f"Encountered np.nan ll with params {pmp}")
            new_ll = -np.inf

        if new_ll > old_ll:
            logger.debug(f"Found direction: {direction * multiplier}; new ll: {new_ll}")
            return direction * multiplier

        multiplier *= 0.8
    raise Exception(
        f"backtracking line search failed, old_ll={old_ll}, new_ll={new_ll}, multiplier={multiplier}, direction={direction}"
    )


def search(sample, p_greater_than_1):
    if not p_greater_than_1:
        # p smaller than 1
        # alpha < hill estimate
        # D > 0
        # bias hill > 0
        # need a beta > alpha
        alpha = hill(sample)
        beta = alpha
        p = 1

        # theta = np.array([alpha, beta, p])
        # direction = np.array([1, 0, -1])
        pmp = pmt.ParetoMixtureParameters(alpha, beta, p)
        logger.debug(pmp)
        direction = pmt.DeltaParetoMixtureParameters(-1, 0, -1)

        direction = backtracking_line_search(sample, pmp, direction, p_greater_than_1, pre_normalize = False)
        pmp = pmp + direction 
        old_ll = pm.loglikelihood(pmp, sample)
        
        n_iterations = 100
        for _ in range(n_iterations):
            logger.debug("-" * 80)
            logger.debug(f"Got new pmp: {pmp}")
            direction = pm.gradient(pmp, sample)
            direction = pmt.DeltaParetoMixtureParameters(
                direction.dll_dalpha, direction.dll_dbeta, direction.dll_dp
            )
            direction = backtracking_line_search(
                sample, pmp, direction, p_greater_than_1, pre_normalize=False
            )
            pmp = pmp + direction
            new_ll = pm.loglikelihood(pmp, sample)
            if (new_ll - old_ll) < 1e-6:
                logger.debug(f"Got final pmp: {pmp}")
                return pmp
            else:
                logger.debug(f"old_ll={old_ll}, new_ll={new_ll}")
            old_ll = new_ll
        raise Exception(f"Did not finish in {n_iterations} iterations")


search(sample, False)
# Out:
# 2023-04-05 21:37:36.160 | DEBUG    | __main__:search:59 - ParetoMixtureParameters(alpha=1.7427129151068517, beta=1.7427129151068517, p=1)
# 2023-04-05 21:37:36.161 | DEBUG    | __main__:backtracking_line_search:8 - Doing backtracking line search in direction DeltaParetoMixtureParameters(dalpha=-1, dbeta=0, dp=-1). Old ll: -314.7635954644528
# 2023-04-05 21:37:36.162 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.2427129151068517, beta=1.7427129151068517, p=0.5)
# 2023-04-05 21:37:36.162 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.3427129151068518, beta=1.7427129151068517, p=0.6)
# 2023-04-05 21:37:36.163 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.4227129151068516, beta=1.7427129151068517, p=0.6799999999999999)
# 2023-04-05 21:37:36.163 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744)
# 2023-04-05 21:37:36.164 | DEBUG    | __main__:backtracking_line_search:36 - Found direction: DeltaParetoMixtureParameters(dalpha=-0.25600000000000006, dbeta=0.0, dp=-0.25600000000000006); new ll: -314.51913287204786
# 2023-04-05 21:37:36.164 | DEBUG    | __main__:search:68 - --------------------------------------------------------------------------------
# 2023-04-05 21:37:36.165 | DEBUG    | __main__:search:69 - Got new pmp: ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256)
# 2023-04-05 21:37:36.165 | DEBUG    | __main__:backtracking_line_search:8 - Doing backtracking line search in direction DeltaParetoMixtureParameters(dalpha=3.201756758690344, dbeta=-0.7212963263636398, dp=-5.7975128242430145). Old ll: -319.6207948662575
# 2023-04-05 21:37:36.166 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=3.599591294452024, beta=1.3820647519250318, p=-1.6427564121215072)
# 2023-04-05 21:37:36.166 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=3.2794156185829895, beta=1.4541943845613958, p=-1.063005129697206)
# 2023-04-05 21:37:36.167 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=3.023275077887762, beta=1.5118980906704869, p=-0.5992041037577649)
# 2023-04-05 21:37:36.167 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=2
| DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# 2023-04-05 21:37:36.227 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.9987129225216138, beta=1.7427129134364434, p=1.2559999865738776)
# 2023-04-05 21:37:36.227 | DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# 2023-04-05 21:37:36.227 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.9987129210386614, beta=1.742712913770525, p=1.255999989259102)
# 2023-04-05 21:37:36.228 | DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# 2023-04-05 21:37:36.228 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.9987129198522995, beta=1.7427129140377904, p=1.2559999914072817)
# 2023-04-05 21:37:36.228 | DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# 2023-04-05 21:37:36.229 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.9987129189032098, beta=1.7427129142516027, p=1.2559999931258252)
# 2023-04-05 21:37:36.229 | DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# 2023-04-05 21:37:36.229 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.9987129181439383, beta=1.7427129144226525, p=1.2559999945006604)
# 2023-04-05 21:37:36.230 | DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# 2023-04-05 21:37:36.230 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.9987129175365208, beta=1.7427129145594924, p=1.255999995600528)
# 2023-04-05 21:37:36.230 | DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# 2023-04-05 21:37:36.231 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.998712917050587, beta=1.7427129146689642, p=1.2559999964804225)
# 2023-04-05 21:37:36.231 | DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# 2023-04-05 21:37:36.231 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.99871291666184, beta=1.7427129147565417, p=1.255999997184338)
# 2023-04-05 21:37:36.232 | DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# 2023-04-05 21:37:36.232 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.9987129163508424, beta=1.7427129148266036, p=1.2559999977474705)
# 2023-04-05 21:37:36.234 | DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# 2023-04-05 21:37:36.234 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.9987129161020443, beta=1.7427129148826532, p=1.2559999981979764)
# 2023-04-05 21:37:36.235 | DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# 2023-04-05 21:37:36.235 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.9987129159030057, beta=1.742712914927493, p=1.2559999985583812)
# 2023-04-05 21:37:36.235 | DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# 2023-04-05 21:37:36.236 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.9987129157437749, beta=1.7427129149633647, p=1.2559999988467048)
# 2023-04-05 21:37:36.236 | DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# 2023-04-05 21:37:36.236 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.9987129156163903, beta=1.7427129149920622, p=1.2559999990773638)
# 2023-04-05 21:37:36.236 | DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# 2023-04-05 21:37:36.237 | DEBUG    | __main__:backtracking_line_search:19 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.9987129155144825, beta=1.74271291501502, p=1.255999999261891)
# 2023-04-05 21:37:36.237 | DEBUG    | __main__:backtracking_line_search:23 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.9987129151068517, beta=1.7427129151068517, p=1.256) where p should be < 1
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 88
#      84             old_ll = new_ll
#      85         raise Exception(f"Did not finish in {n_iterations} iterations")
# ---> 88 search(sample, False)
#
# Cell In[14], line 74, in search(sample, p_greater_than_1)
#      70 direction = pm.gradient(pmp, sample)
#      71 direction = pmt.DeltaParetoMixtureParameters(
#      72     -direction.dll_dalpha, -direction.dll_dbeta, -direction.dll_dp
#      73 )
# ---> 74 direction = backtracking_line_search(
#      75     sample, pmp, direction, p_greater_than_1, pre_normalize=False
#      76 ) * -1
#      77 pmp = pmp + direction
#      78 new_ll = pm.loglikelihood(pmp, sample)
#
# Cell In[14], line 40, in backtracking_line_search(sample, pmp, direction, p_greater_than_1, pre_normalize)
#      37         return direction * multiplier
#      39     multiplier *= 0.8
# ---> 40 raise Exception(
#      41     f"backtracking line search failed, old_ll={old_ll}, new_ll={new_ll}, multiplier={multiplier}, direction={direction}"
#      42 )
#
# Exception: backtracking line search failed, old_ll=-319.6207948662575, new_ll=-inf, multiplier=1.0185179881672491e-10, direction=DeltaParetoMixtureParameters(dalpha=3.201756758690344, dbeta=-0.7212963263636398, dp=-5.7975128242430145)
