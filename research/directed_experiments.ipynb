# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import seaborn as sns
import pyparetomixture.fit as pm
import pyparetomixture.type as pmt
from loguru import logger
import sys

logger.remove()
logger.add(sys.stdout, colorize=True, level="DEBUG")
None

# %%
# generate data
n = 10000
p = 0.95
alpha = 2.0
beta = 3.0  # beta > alpha


def generate_data(n, p, alpha, beta):
    x = np.random.binomial(1, p, n)
    rv_alpha = np.random.pareto(alpha, n)
    rv_beta = np.random.pareto(beta, n)
    return x * rv_alpha + (1 - x) * rv_beta


data = generate_data(n, p, alpha, beta)
logger.debug(
    f"Generated a sample of length {len(data)}. Mean: {np.mean(data)}, std: {np.std(data)}"
)
# Out:
# 2023-04-05 20:28:24.035 | DEBUG    | __main__:<module>:16 - Generated a sample of length 10000. Mean: 0.9488068780987603, std: 2.2457484351925068

# %%
def pot(full_sample, k):
    full_sample.sort()
    return (full_sample[-k:] / full_sample[-k - 1]).copy()


def hill(sample):
    # hill estimate
    k = len(sample)
    assert (sample >= 1).all(), "not a pot sample"
    return k / (np.sum(np.log(sample)))


sample = pot(data, 200)
logger.debug(f"Generated pot sample. Min: {np.min(sample)}, max: {np.max(sample)}")
# Out:
# 2023-04-05 20:28:24.101 | DEBUG    | __main__:<module>:14 - Generated pot sample. Min: 1.000728990410609, max: 12.468327486729253

# %%
def backtracking_line_search(
    sample, pmp, direction, p_greater_than_1, pre_normalize=True
):
    # backtracking line search
    # https://en.wikipedia.org/wiki/Backtracking_line_search

    old_ll = pm.loglikelihood(pmp, sample)
    logger.debug(
        f"Doing backtracking line search in direction {direction}. Old ll: {old_ll}"
    )

    if pre_normalize:
        direction = direction * (1 / np.linalg.norm(np.array([direction.dalpha, direction.dbeta, direction.dp])))
        logger.debug(f"We normalize our direction: {direction}")

    multiplier = 0.5
    n_iterations = 100
    for i in range(n_iterations):
        new_pmp = pmp + direction * multiplier

        logger.debug(f"New pmp in backtracking line search: {new_pmp}")
        # we ensure our new pmp do not surpass the thresholds we are given
        if not p_greater_than_1 and new_pmp.p >= 1:
            logger.debug(f"Encountered p >= 1 in {pmp} where p should be < 1")
            new_ll = -np.inf
        elif p_greater_than_1 and new_pmp.p <= 1:
            logger.debug(f"Encountered p <= 1 in {pmp} where p should be > 1")
            new_ll = -np.inf
        else:
            new_ll = pm.loglikelihood(new_pmp, sample)

        if new_ll == np.nan:
            logger.debug(f"Encountered np.nan ll with params {pmp}")
            new_ll = -np.inf

        logger.debug(f"Its likelihood is {new_ll}")

        if new_ll > old_ll:
            logger.debug(f"Found direction: {direction * multiplier}; new ll: {new_ll}")
            return direction * multiplier
        elif i > (n_iterations - 20) and new_ll > old_ll - 1e-5:
            logger.debug("Making a step for the sake of it.")
            return direction * multiplier

        multiplier *= 0.8
    raise Exception(
        f"backtracking line search did not converge in {n_iterations}, old_ll={old_ll}, new_ll={new_ll}, multiplier={multiplier}, direction={direction}"
    )


def search(sample, p_greater_than_1):
    if not p_greater_than_1:
        # p smaller than 1
        # alpha < hill estimate
        # D > 0
        # bias hill > 0
        # need a beta > alpha
        alpha = hill(sample)
        beta = alpha
        p = 1

        # theta = np.array([alpha, beta, p])
        # direction = np.array([1, 0, -1])
        pmp = pmt.ParetoMixtureParameters(alpha, beta, p)
        logger.debug(pmp)
        direction = pmt.DeltaParetoMixtureParameters(-1, 0, -1)

        direction = backtracking_line_search(sample, pmp, direction, p_greater_than_1, pre_normalize = False)
        pmp = pmp + direction 
        old_ll = pm.loglikelihood(pmp, sample)
        
        n_iterations = 100
        for _ in range(n_iterations):
            logger.debug("-" * 80)
            logger.debug(f"Got new pmp: {pmp}")
            direction = pm.gradient(pmp, sample)
            direction = pmt.DeltaParetoMixtureParameters(
                direction.dll_dalpha, direction.dll_dbeta, direction.dll_dp
            )
            direction = backtracking_line_search(
                sample, pmp, direction, p_greater_than_1, pre_normalize=False
            )
            pmp = pmp + direction
            new_ll = pm.loglikelihood(pmp, sample)
            if (new_ll - old_ll) < 1e-6:
                logger.debug(f"Got final pmp: {pmp}")
                return pmp
            else:
                logger.debug(f"old_ll={old_ll}, new_ll={new_ll}")
            old_ll = new_ll
        raise Exception(f"Did not finish in {n_iterations} iterations")


pmp = search(sample, False)
pmp
# Out:
# 2023-04-05 21:47:15.982 | DEBUG    | __main__:search:65 - ParetoMixtureParameters(alpha=1.7427129151068517, beta=1.7427129151068517, p=1)
# 2023-04-05 21:47:15.983 | DEBUG    | __main__:backtracking_line_search:8 - Doing backtracking line search in direction DeltaParetoMixtureParameters(dalpha=-1, dbeta=0, dp=-1). Old ll: -314.7635954644528
# 2023-04-05 21:47:15.984 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.2427129151068517, beta=1.7427129151068517, p=0.5)
# 2023-04-05 21:47:15.984 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -320.9207414948673
# 2023-04-05 21:47:15.984 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.3427129151068518, beta=1.7427129151068517, p=0.6)
# 2023-04-05 21:47:15.985 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -317.2852276544995
# 2023-04-05 21:47:15.985 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.4227129151068516, beta=1.7427129151068517, p=0.6799999999999999)
# 2023-04-05 21:47:15.986 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -315.4351735159346
# 2023-04-05 21:47:15.986 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744)
# 2023-04-05 21:47:15.987 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -314.51913287204786
# 2023-04-05 21:47:15.987 | DEBUG    | __main__:backtracking_line_search:39 - Found direction: DeltaParetoMixtureParameters(dalpha=-0.25600000000000006, dbeta=0.0, dp=-0.25600000000000006); new ll: -314.51913287204786
# 2023-04-05 21:47:15.987 | DEBUG    | __main__:search:74 - --------------------------------------------------------------------------------
# 2023-04-05 21:47:15.988 | DEBUG    | __main__:search:75 - Got new pmp: ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744)
# 2023-04-05 21:47:15.988 | DEBUG    | __main__:backtracking_line_search:8 - Doing backtracking line search in direction DeltaParetoMixtureParameters(dalpha=1.809682673840598, dbeta=-1.963412711153505, dp=9.148927702246901). Old ll: -314.51913287204786
# 2023-04-05 21:47:15.989 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=2.3915542520271504, beta=0.7610065595300992, p=5.31846385112345)
# 2023-04-05 21:47:15.990 | DEBUG    | __main__:backtracking_line_search:24 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744) where p should be < 1
# 2023-04-05 21:47:15.991 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -inf
# 2023-04-05 21:47:15.991 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=2.2105859846430906, beta=0.9573478306454497, p=4.403571080898761)
# 2023-04-05 21:47:15.991 | DEBUG    | __main__:backtracking_line_search:24 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744) where p should be < 1
# 2023-04-05 21:47:15.992 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -inf
# 2023-04-05 21:47:15.992 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=2.065811370735843, beta=1.11442084753773, p=3.671656864719009)
# 2023-04-05 21:47:15.992 | DEBUG    | __main__:backtracking_line_search:24 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744) where p should be < 1
# 2023-04-05 21:47:15.993 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -inf
# 2023-04-05 21:47:15.993 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.949991679610045, beta=1.2400792610515543, p=3.0861254917752072)
# 2023-04-05 21:47:15.993 | DEBUG    | __main__:backtracking_line_search:24 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744) where p should be < 1
# 2023-04-05 21:47:15.994 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -inf
# 2023-04-05 21:47:15.994 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.8573359267094063, beta=1.3406059918626139, p=2.617700393420166)
# 2023-04-05 21:47:15.995 | DEBUG    | __main__:backtracking_line_search:24 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744) where p should be < 1
# 2023-04-05 21:47:15.995 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -inf
# 2023-04-05 21:47:15.995 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.7832113243888954, beta=1.4210273765114612, p=2.242960314736133)
# 2023-04-05 21:47:15.996 | DEBUG    | __main__:backtracking_line_search:24 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744) where p should be < 1
# 2023-04-05 21:47:15.997 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -inf
# 2023-04-05 21:47:15.997 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.7239116425324865, beta=1.4853644842305394, p=1.9431682517889062)
# 2023-04-05 21:47:15.998 | DEBUG    | __main__:backtracking_line_search:24 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744) where p should be < 1
# 2023-04-05 21:47:15.998 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -inf
# 2023-04-05 21:47:15.998 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.6764718970473595, beta=1.5368341704058017, p=1.7033346014311253)
# 2023-04-05 21:47:15.999 | DEBUG    | __main__:backtracking_line_search:24 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744) where p should be < 1
# 2023-04-05 21:47:15.999 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -inf
# 2023-04-05 21:47:15.999 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.638520100659258, beta=1.5780099193460118, p=1.5114676811449002)
# 2023-04-05 21:47:16.000 | DEBUG    | __main__:backtracking_line_search:24 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744) where p should be < 1
# 2023-04-05 21:47:16.000 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -inf
# 2023-04-05 21:47:16.001 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.6081586635487768, beta=1.6109505184981798, p=1.3579741449159202)
# 2023-04-05 21:47:16.001 | DEBUG    | __main__:backtracking_line_search:24 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744) where p should be < 1
# 2023-04-05 21:47:16.001 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -inf
# 2023-04-05 21:47:16.002 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5838695138603918, beta=1.637302997819914, p=1.235179315932736)
# 2023-04-05 21:47:16.003 | DEBUG    | __main__:backtracking_line_search:24 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744) where p should be < 1
# 2023-04-05 21:47:16.003 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -inf
# 2023-04-05 21:47:16.003 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5644381941096837, beta=1.6583849812773017, p=1.136943452746189)
# 2023-04-05 21:47:16.004 | DEBUG    | __main__:backtracking_line_search:24 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744) where p should be < 1
# 2023-04-05 21:47:16.004 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -inf
# 2023-04-05 21:47:16.004 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5488931383091173, beta=1.6752505680432117, p=1.0583547621969511)
# 2023-04-05 21:47:16.005 | DEBUG    | __main__:backtracking_line_search:24 - Encountered p >= 1 in ParetoMixtureParameters(alpha=1.4867129151068517, beta=1.7427129151068517, p=0.744) where p should be < 1
# 2023-04-05 21:47:16.005 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -inf
# 2023-04-05 21:47:16.006 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5364570936686641, beta=1.6887430374559396, p=0.9954838097575609)
# 2023-04-05 21:47:16.006 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.55427768002
# 2023-04-05 21:47:16.006 | DEBUG    | __main__:backtracking_line_search:39 - Found direction: DeltaParetoMixtureParameters(dalpha=0.049744178561812534, dbeta=-0.053969877650912025, dp=0.2514838097575609); new ll: -291.55427768002
# 2023-04-05 21:47:16.007 | DEBUG    | __main__:search:89 - old_ll=-314.51913287204786, new_ll=-291.55427768002
# 2023-04-05 21:47:16.007 | DEBUG    | __main__:search:74 - --------------------------------------------------------------------------------
# 2023-04-05 21:47:16.007 | DEBUG    | __main__:search:75 - Got new pmp: ParetoMixtureParameters(alpha=1.5364570936686641, beta=1.6887430374559396, p=0.9954838097575609)
# 2023-04-05 21:47:16.008 | DEBUG    | __main__:backtracking_line_search:8 - Doing backtracking line search in direction DeltaParetoMixtureParameters(dalpha=15.089898644174038, dbeta=-0.007258275418255564, dp=-5.409636426595867). Old ll: -291.55427768002
# 2023-04-05 21:47:16.010 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=9.081406415755684, beta=1.6851138997468118, p=-1.7093344035403726)
# 2023-04-05 21:47:16.010 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is nan
# 2023-04-05 21:47:16.010 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=7.57241655133828, beta=1.6858397272886374, p=-1.168370760880786)
# 2023-04-05 21:47:16.011 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is nan
# 2023-04-05 21:47:16.011 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=6.365224659804357, beta=1.6864203893220977, p=-0.7355998467531168)
# 2023-04-05 21:47:16.012 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is nan
# 2023-04-05 21:47:16.012 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=5.399471146577219, beta=1.6868849189488662, p=-0.3893831154509815)
# 2023-04-05 21:47:16.013 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is nan
# 2023-04-05 21:47:16.013 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=4.626868335995508, beta=1.6872565426502808, p=-0.11240973040927305)
# 2023-04-05 21:47:16.014 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is nan
# 2023-04-05 21:47:16.014 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=4.008786087530139, beta=1.6875538416114126, p=0.10916897762409372)
# 2023-04-05 21:47:16.014 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -720.8819807889715
# 2023-04-05 21:47:16.015 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha
| DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.5545714545306
# 2023-04-05 21:47:16.071 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.536458645574726, beta=1.6887430367094693, p=0.9954832534087238)
# 2023-04-05 21:47:16.071 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.55451269962583
# 2023-04-05 21:47:16.072 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5364583351935135, beta=1.6887430368587633, p=0.9954833646784912)
# 2023-04-05 21:47:16.072 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.554465695703
# 2023-04-05 21:47:16.072 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5364580868885436, beta=1.6887430369781986, p=0.9954834536943051)
# 2023-04-05 21:47:16.073 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.55442809256533
# 2023-04-05 21:47:16.073 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5364578882445679, beta=1.6887430370737468, p=0.9954835249069564)
# 2023-04-05 21:47:16.073 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.5543980100556
# 2023-04-05 21:47:16.074 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.536457729329387, beta=1.6887430371501853, p=0.9954835818770772)
# 2023-04-05 21:47:16.074 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.55437394404805
# 2023-04-05 21:47:16.075 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5364576021972425, beta=1.6887430372113361, p=0.995483627453174)
# 2023-04-05 21:47:16.075 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.55435469124217
# 2023-04-05 21:47:16.075 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5364575004915269, beta=1.6887430372602568, p=0.9954836639140513)
# 2023-04-05 21:47:16.076 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.5543392889975
# 2023-04-05 21:47:16.076 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5364574191269542, beta=1.6887430372993935, p=0.9954836930827533)
# 2023-04-05 21:47:16.077 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.55432696720186
# 2023-04-05 21:47:16.077 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5364573540352962, beta=1.6887430373307026, p=0.9954837164177148)
# 2023-04-05 21:47:16.077 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.5543171097654
# 2023-04-05 21:47:16.078 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5364573019619698, beta=1.68874303735575, p=0.995483735085684)
# 2023-04-05 21:47:16.078 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.55430922381623
# 2023-04-05 21:47:16.078 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5364572603033086, beta=1.688743037375788, p=0.9954837500200594)
# 2023-04-05 21:47:16.079 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.554302915057
# 2023-04-05 21:47:16.081 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5364572269763797, beta=1.6887430373918182, p=0.9954837619675597)
# 2023-04-05 21:47:16.081 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.5542978680495
# 2023-04-05 21:47:16.081 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5364572003148367, beta=1.6887430374046426, p=0.9954837715255599)
# 2023-04-05 21:47:16.082 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.55429383044367
# 2023-04-05 21:47:16.082 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.536457178985602, beta=1.688743037414902, p=0.9954837791719602)
# 2023-04-05 21:47:16.083 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.55429060035885
# 2023-04-05 21:47:16.083 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5364571619222145, beta=1.6887430374231094, p=0.9954837852890803)
# 2023-04-05 21:47:16.083 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.55428801629114
# 2023-04-05 21:47:16.084 | DEBUG    | __main__:backtracking_line_search:21 - New pmp in backtracking line search: ParetoMixtureParameters(alpha=1.5364571482715044, beta=1.6887430374296755, p=0.9954837901827764)
# 2023-04-05 21:47:16.084 | DEBUG    | __main__:backtracking_line_search:36 - Its likelihood is -291.55428594903685
# 2023-04-05 21:47:16.084 | DEBUG    | __main__:backtracking_line_search:42 - Making a step for the sake of it.
# 2023-04-05 21:47:16.085 | DEBUG    | __main__:search:86 - Got final pmp: ParetoMixtureParameters(alpha=1.5364571482715044, beta=1.6887430374296755, p=0.9954837901827764)
# /home/maurits/private/pareto_mixture/src/pyparetomixture/fit.py:92: RuntimeWarning: invalid value encountered in log
#   dll_dalpha2 = np.sum(
# ParetoMixtureParameters(alpha=1.5364571482715044, beta=1.6887430374296755, p=0.9954837901827764)

# %%
pm.gradient(pmp, sample)
# Out:
# Gradient(dll_dalpha=15.089892672686165, dll_dbeta=-0.007258314053641579, dll_dp=-5.409631303810023)
